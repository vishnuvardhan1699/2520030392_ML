# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.2
# NumPy          : 2.0.2
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
import pandas as pd
import seaborn as sns
from pandas import read_csv
df=read_csv('/content/placement_predict_50k Dataset (1).csv')

# %%
#Displays the last five records of the dataset.
df.tail(5)
# Out:
#        StudentID  Gender       City CollegeTier Stream Specialisation Hostel  \
# 23873      23874    Male      Kochi       Tier3    ECE    DataScience    Yes
# 23874      23875  Female  Bangalore       Tier2    ECE     Networking    Yes
# 23875      23876    Male  Hyderabad       Tier1     IT    DataScience     No
# 23876      23877  Female     Mumbai       Tier2     CS       Embedded    Yes
# 23877      23878  Female  Hyderabad       Tier2    ECE       Embedded    Yes
#
#       HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Certifications  \
# 23873                No       8.27       7.61  ...             1.0
# 23874                No       6.40       7.37  ...             1.0
# 23875                No       6.72       6.37  ...             2.0
# 23876                No       8.36       7.99  ...             3.0
# 23877                No       6.33       6.59  ...             NaN
#
#        Publications  AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# 23873           0.0               57.2               3.2              NaN
# 23874           1.0               72.1               NaN             69.4
# 23875           0.0               59.4               2.7             59.3
# 23876           1.0               91.8               3.8             62.3
# 23877           NaN                NaN               NaN              NaN
#
#        MockInterviewScore  ExtraCurricular  CGPA_Tier  PlacementStatus  \
# 23873                62.0              1.0       High              1.0
# 23874                47.8              1.0        Mid              1.0
# 23875                53.5              0.0        Mid              0.0
# 23876                75.1              0.0       High              1.0
# 23877                 NaN              NaN        NaN              NaN
#
#        IsAnomaly
# 23873        0.0
# 23874        0.0
# 23875        0.0
# 23876        0.0
# 23877        NaN
#
# [5 rows x 31 columns]

# %%
df['StudentID']
df.shape
# Out:
# (23878, 31)

# %%
df.head(5)
# Out:
#    StudentID  Gender       City CollegeTier Stream Specialisation Hostel  \
# 0          1    Male  Ahmedabad       Tier2    ECE     Networking     No
# 1          2  Female     Mumbai       Tier2    ECE    DataScience    Yes
# 2          3    Male    Kolkata       Tier2     IT    DataScience    Yes
# 3          4    Male     Jaipur       Tier1     CS             AI     No
# 4          5    Male       Pune       Tier2     IT    DataScience    Yes
#
#   HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Certifications  Publications  \
# 0                No       6.02       6.54  ...             2.0           0.0
# 1               Yes       5.84       5.12  ...             1.0           0.0
# 2                No       4.91       5.29  ...             1.0           0.0
# 3                No       7.67       8.03  ...             2.0           0.0
# 4                No       8.14       8.97  ...             4.0           1.0
#
#    AptitudeTestScore  SoftSkillsRating  CodingTestScore  MockInterviewScore  \
# 0               66.7               2.2             49.4                47.8
# 1               48.2               2.4             26.7                25.8
# 2               73.8               2.8             67.7                41.5
# 3               69.8               2.7             66.9                48.0
# 4               73.1               2.1             71.7                61.7
#
#    ExtraCurricular  CGPA_Tier  PlacementStatus  IsAnomaly
# 0              0.0        Low              0.0        0.0
# 1              0.0        Low              0.0        0.0
# 2              0.0        Low              1.0        0.0
# 3              0.0        Mid              1.0        0.0
# 4              1.0       High              1.0        0.0
#
# [5 rows x 31 columns]

# %%
df.dtypes
# Out:
# StudentID               int64
# Gender                 object
# City                   object
# CollegeTier            object
# Stream                 object
# Specialisation         object
# Hostel                 object
# HistoryOfBacklogs      object
# SGPA_Sem1             float64
# SGPA_Sem2             float64
# SGPA_Sem3             float64
# SGPA_Sem4             float64
# SGPA_Sem5             float64
# SGPA_Sem6             float64
# SGPA_Sem7             float64
# SGPA_Sem8             float64
# CGPA                  float64
# AttendancePercent     float64
# Internships           float64
# Projects              float64
# Workshops             float64
# Certifications        float64
# Publications          float64
# AptitudeTestScore     float64
# SoftSkillsRating      float64
# CodingTestScore       float64
# MockInterviewScore    float64
# ExtraCurricular       float64
# CGPA_Tier              object
# PlacementStatus       float64
# IsAnomaly             float64
# dtype: object

# %%
df['StudentID']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 23873    23874
# 23874    23875
# 23875    23876
# 23876    23877
# 23877    23878
# Name: StudentID, Length: 23878, dtype: int64

# %%
df['City']
# Out:
# 0        Ahmedabad
# 1           Mumbai
# 2          Kolkata
# 3           Jaipur
# 4             Pune
#            ...
# 23873        Kochi
# 23874    Bangalore
# 23875    Hyderabad
# 23876       Mumbai
# 23877    Hyderabad
# Name: City, Length: 23878, dtype: object

# %%
df['Internships']
# Out:
# 0        1.0
# 1        0.0
# 2        1.0
# 3        1.0
# 4        2.0
#         ...
# 23873    1.0
# 23874    1.0
# 23875    1.0
# 23876    2.0
# 23877    NaN
# Name: Internships, Length: 23878, dtype: float64

# %%
df['AptitudeTestScore']
# Out:
# 0        66.7
# 1        48.2
# 2        73.8
# 3        69.8
# 4        73.1
#          ...
# 23873    57.2
# 23874    72.1
# 23875    59.4
# 23876    91.8
# 23877     NaN
# Name: AptitudeTestScore, Length: 23878, dtype: float64

# %%
df['CGPA']
# Out:
# 0        6.29
# 1        5.23
# 2        5.52
# 3        7.51
# 4        8.65
#          ...
# 23873    8.06
# 23874    7.45
# 23875    6.55
# 23876    8.60
# 23877     NaN
# Name: CGPA, Length: 23878, dtype: float64

# %%
df['Stream']
# Out:
# 0        ECE
# 1        ECE
# 2         IT
# 3         CS
# 4         IT
#         ...
# 23873    ECE
# 23874    ECE
# 23875     IT
# 23876     CS
# 23877    ECE
# Name: Stream, Length: 23878, dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    22
# object      8
# int64       1
# Name: count, dtype: int64

# %%
missing_data = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})
missing_data
# Out:
#                     Missing Values  Percentage
# StudentID                        0    0.000000
# Gender                           0    0.000000
# City                             0    0.000000
# CollegeTier                      0    0.000000
# Stream                           0    0.000000
# Specialisation                   0    0.000000
# Hostel                           0    0.000000
# HistoryOfBacklogs                0    0.000000
# SGPA_Sem1                        0    0.000000
# SGPA_Sem2                        0    0.000000
# SGPA_Sem3                        0    0.000000
# SGPA_Sem4                        0    0.000000
# SGPA_Sem5                        0    0.000000
# SGPA_Sem6                        0    0.000000
# SGPA_Sem7                        1    0.004188
# SGPA_Sem8                        1    0.004188
# CGPA                             1    0.004188
# AttendancePercent                1    0.004188
# Internships                      1    0.004188
# Projects                         1    0.004188
# Workshops                     2164    9.062736
# Certifications                   1    0.004188
# Publications                     1    0.004188
# AptitudeTestScore             1926    8.066002
# SoftSkillsRating              1649    6.905939
# CodingTestScore               1434    6.005528
# MockInterviewScore            2367    9.912891
# ExtraCurricular                  1    0.004188
# CGPA_Tier                        1    0.004188
# PlacementStatus                  1    0.004188
# IsAnomaly                        1    0.004188

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
# cbar=False hides the color bar; yticklabels=False hides row numbers for cleaner v
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("missing")
plt.show()

# %%
#Keeps the first occurrence and marks subsequent duplicates as True(if any)
duplicate_rows = df[df.duplicated()]
print(f"Total duplicate rows detected: {len(duplicate_rows)}")
print(duplicate_rows)
print("-" * 40)
# Out:
# Total duplicate rows detected: 0
# Empty DataFrame
# Columns: [StudentID, Gender, City, CollegeTier, Stream, Specialisation, Hostel, HistoryOfBacklogs, SGPA_Sem1, SGPA_Sem2, SGPA_Sem3, SGPA_Sem4, SGPA_Sem5, SGPA_Sem6, SGPA_Sem7, SGPA_Sem8, CGPA, AttendancePercent, Internships, Projects, Workshops, Certifications, Publications, AptitudeTestScore, SoftSkillsRating, CodingTestScore, MockInterviewScore, ExtraCurricular, CGPA_Tier, PlacementStatus, IsAnomaly]
# Index: []
#
# [0 rows x 31 columns]
# ----------------------------------------

# %%
#display rows where null values are present if any
df[df['AptitudeTestScore'].isnull()]
# Out:
#        StudentID  Gender       City CollegeTier      Stream Specialisation  \
# 7              8    Male      Delhi       Tier2  Mechanical       Embedded
# 13            14    Male      Delhi       Tier1          CS             AI
# 18            19    Male  Bangalore       Tier2  Mechanical       Embedded
# 29            30  Female       Pune       Tier2       Civil     Networking
# 33            34    Male      Kochi       Tier3       Civil             AI
# ...          ...     ...        ...         ...         ...            ...
# 23798      23799    Male      Kochi       Tier2          CS             AI
# 23801      23802    Male     Mumbai       Tier3          CS     Networking
# 23851      23852    Male  Hyderabad       Tier1          CS             AI
# 23866      23867    Male  Hyderabad       Tier1  Mechanical       Embedded
# 23877      23878  Female  Hyderabad       Tier2         ECE       Embedded
#
#       Hostel HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Certifications  \
# 7        Yes                No       5.87       5.64  ...             0.0
# 13        No                No      10.00      10.00  ...             3.0
# 18        No                No       6.97       6.53  ...             1.0
# 29       Yes                No       9.94       9.85  ...             3.0
# 33       Yes                No       4.52       4.06  ...             1.0
# ...      ...               ...        ...        ...  ...             ...
# 23798     No                No       7.53       7.37  ...             2.0
# 23801    Yes               Yes       6.54       6.50  ...             1.0
# 23851    Yes                No       8.75       8.83  ...             3.0
# 23866    Yes                No       6.98       7.15  ...             3.0
# 23877    Yes                No       6.33       6.59  ...             NaN
#
#        Publications  AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# 7               0.0                NaN               2.0             35.2
# 13              1.0                NaN               NaN             87.9
# 18              0.0                NaN               1.3             57.9
# 29              2.0                NaN               4.8             60.3
# 33              1.0                NaN               2.1             27.4
# ...             ...                ...               ...              ...
# 23798           0.0                NaN               3.3             54.0
# 23801           0.0                NaN               2.7             54.6
# 23851           2.0                NaN               4.8             95.0
# 23866           2.0                NaN               3.7             96.0
# 23877           NaN                NaN               NaN              NaN
#
#        MockInterviewScore  ExtraCurricular  CGPA_Tier  PlacementStatus  \
# 7                    27.8              0.0        Low              0.0
# 13                   86.8              1.0       High              1.0
# 18                   56.6              0.0        Mid              0.0
# 29                   89.3              1.0       High              1.0
# 33                   34.6              1.0        Low              0.0
# ...                   ...              ...        ...              ...
# 23798                52.8              1.0        Mid              0.0
# 23801                42.5              0.0        Mid              0.0
# 23851                72.0              1.0       High              1.0
# 23866                61.0              1.0        Mid              1.0
# 23877                 NaN              NaN        NaN              NaN
#
#        IsAnomaly
# 7            0.0
# 13           0.0
# 18           0.0
# 29           0.0
# 33           0.0
# ...          ...
# 23798        0.0
# 23801        0.0
# 23851        0.0
# 23866        0.0
# 23877        NaN
#
# [1926 rows x 31 columns]

# %%
#  Checking for Duplicates

df.duplicated().sum()
df = df.drop_duplicates()

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (23878, 31)

# %%
df.describe()
# Out:
#         StudentID     SGPA_Sem1     SGPA_Sem2     SGPA_Sem3     SGPA_Sem4  \
# count  23878.0000  23878.000000  23878.000000  23878.000000  23878.000000
# mean   11939.5000      7.209415      7.219609      7.231611      7.242624
# std     6893.1292      1.513219      1.530844      1.548950      1.568309
# min        1.0000      4.000000      4.000000      4.000000      4.000000
# 25%     5970.2500      6.090000      6.080000      6.080000      6.060000
# 50%    11939.5000      7.200000      7.210000      7.230000      7.250000
# 75%    17908.7500      8.320000      8.350000      8.380000      8.410000
# max    23878.0000     10.000000     10.000000     10.000000     10.000000
#
#           SGPA_Sem5     SGPA_Sem6     SGPA_Sem7     SGPA_Sem8          CGPA  \
# count  23878.000000  23878.000000  23877.000000  23877.000000  23877.000000
# mean       7.254263      7.269709      7.276908      7.288973      7.242742
# std        1.583451      1.602076      1.621372      1.637648      1.614211
# min        4.000000      4.000000      4.000000      4.000000      4.000000
# 25%        6.080000      6.070000      6.050000      6.050000      6.030000
# 50%        7.260000      7.280000      7.290000      7.310000      7.260000
# 75%        8.457500      8.490000      8.510000      8.560000      8.470000
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#        ...     Workshops  Certifications  Publications  AptitudeTestScore  \
# count  ...  21714.000000    23877.000000  23877.000000       21952.000000
# mean   ...      1.797964        1.919420      0.731960          68.634366
# std    ...      1.036849        1.170986      0.720501          15.378214
# min    ...      0.000000        0.000000      0.000000          30.000000
# 25%    ...      1.000000        1.000000      0.000000          58.100000
# 50%    ...      2.000000        2.000000      1.000000          69.600000
# 75%    ...      3.000000        3.000000      1.000000          79.500000
# max    ...      4.000000        5.000000      3.000000         100.000000
#
#        SoftSkillsRating  CodingTestScore  MockInterviewScore  ExtraCurricular  \
# count      22229.000000     22444.000000        21511.000000     23877.000000
# mean           3.146466        57.237453           55.261448         0.531976
# std            0.982685        21.030860           17.509948         0.498987
# min            1.000000         0.000000           15.900000         0.000000
# 25%            2.400000        45.600000           43.950000         0.000000
# 50%            3.100000        57.500000           54.600000         1.000000
# 75%            3.900000        73.100000           68.900000         1.000000
# max            5.000000       100.000000          100.000000         1.000000
#
#        PlacementStatus     IsAnomaly
# count     23877.000000  23877.000000
# mean          0.655484      0.035683
# std           0.475220      0.185502
# min           0.000000      0.000000
# 25%           0.000000      0.000000
# 50%           1.000000      0.000000
# 75%           1.000000      0.000000
# max           1.000000      1.000000
#
# [8 rows x 23 columns]

# %%
df["PlacementStatus"].value_counts()
# Out:
# PlacementStatus
# 1.0    15651
# 0.0     8226
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
# Numerical vs Categorical features
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df.select_dtypes(include=['object']).columns

print("Numerical Features:", list(numerical_features))
print("Categorical Features:", list(categorical_features))
# Out:
# Numerical Features: ['StudentID', 'SGPA_Sem1', 'SGPA_Sem2', 'SGPA_Sem3', 'SGPA_Sem4', 'SGPA_Sem5', 'SGPA_Sem6', 'SGPA_Sem7', 'SGPA_Sem8', 'CGPA', 'AttendancePercent', 'Internships', 'Projects', 'Workshops', 'Certifications', 'Publications', 'AptitudeTestScore', 'SoftSkillsRating', 'CodingTestScore', 'MockInterviewScore', 'ExtraCurricular', 'PlacementStatus', 'IsAnomaly']
# Categorical Features: ['Gender', 'City', 'CollegeTier', 'Stream', 'Specialisation', 'Hostel', 'HistoryOfBacklogs', 'CGPA_Tier']

# %%
# Select only numerical columns for correlation
numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()
corr_matrix = df[numerical_cols].corr()

# %%
print("\n--- Correlation Matrix ---")
print(corr_matrix)
# Out:
# --- Correlation Matrix ---
#                     StudentID  SGPA_Sem1  SGPA_Sem2  SGPA_Sem3  SGPA_Sem4  \
# StudentID            1.000000  -0.016576  -0.017491  -0.018859  -0.016454
# SGPA_Sem1           -0.016576   1.000000   0.963827   0.963820   0.963593
# SGPA_Sem2           -0.017491   0.963827   1.000000   0.964666   0.965021
# SGPA_Sem3           -0.018859   0.963820   0.964666   1.000000   0.965465
# SGPA_Sem4           -0.016454   0.963593   0.965021   0.965465   1.000000
# SGPA_Sem5           -0.017645   0.962790   0.964697   0.965666   0.966458
# SGPA_Sem6           -0.015824   0.962064   0.964111   0.965788   0.966324
# SGPA_Sem7           -0.018344   0.961632   0.963817   0.965107   0.965861
# SGPA_Sem8           -0.019364   0.960387   0.963215   0.964905   0.966228
# CGPA                -0.014992   0.910426   0.911858   0.912324   0.912467
# AttendancePercent   -0.006757   0.498935   0.509160   0.517268   0.525361
# Internships         -0.007899   0.445518   0.455512   0.461367   0.466657
# Projects            -0.013979   0.503689   0.513608   0.522578   0.529857
# Workshops           -0.015969   0.534127   0.545746   0.554457   0.564005
# Certifications      -0.014361   0.549925   0.561511   0.569837   0.579227
# Publications        -0.007597   0.459422   0.468174   0.475172   0.484261
# AptitudeTestScore   -0.002452   0.494362   0.507290   0.515613   0.522049
# SoftSkillsRating    -0.015393   0.521907   0.532473   0.540142   0.548881
# CodingTestScore     -0.007285   0.547556   0.558873   0.566620   0.575112
# MockInterviewScore  -0.009893   0.607211   0.619693   0.629323   0.638837
# ExtraCurricular      0.000922   0.216576   0.220108   0.224884   0.224984
# PlacementStatus     -0.011653   0.666083   0.673924   0.677951   0.684598
# IsAnomaly           -0.005638  -0.004832  -0.002001  -0.002647  -0.006361
#
#                     SGPA_Sem5  SGPA_Sem6  SGPA_Sem7  SGPA_Sem8      CGPA  ...  \
# StudentID           -0.017645  -0.015824  -0.018344  -0.019364 -0.014992  ...
# SGPA_Sem1            0.962790   0.962064   0.961632   0.960387  0.910426  ...
# SGPA_Sem2            0.964697   0.964111   0.963817   0.963215  0.911858  ...
# SGPA_Sem3            0.965666   0.965788   0.965107   0.964905  0.912324  ...
# SGPA_Sem4            0.966458   0.966324   0.965861   0.966228  0.912467  ...
# SGPA_Sem5            1.000000   0.967258   0.967081   0.967514  0.912419  ...
# SGPA_Sem6            0.967258   1.000000   0.968027   0.968321  0.912917  ...
# SGPA_Sem7            0.967081   0.968027   1.000000   0.968743  0.912858  ...
# SGPA_Sem8            0.967514   0.968321   0.968743   1.000000  0.912284  ...
# CGPA                 0.912419   0.912917   0.912858   0.912284  1.000000  ...
# AttendancePercent    0.534346   0.541959   0.546529   0.553666  0.570108  ...
# Internships          0.474030   0.482144   0.487437   0.495367  0.521094  ...
# Projects             0.538681   0.548245   0.552696   0.561033  0.585279  ...
# Workshops            0.571617   0.581184   0.586307   0.594862  0.531254  ...
# Certifications       0.589445   0.598372   0.604930   0.611920  0.549611  ...
# Publications         0.491019   0.498286   0.503585   0.510204  0.460152  ...
# AptitudeTestScore    0.531273   0.540566   0.546251   0.552795  0.642761  ...
# SoftSkillsRating     0.559549   0.567194   0.572416   0.580684  0.520043  ...
# CodingTestScore      0.583649   0.593697   0.599674   0.608087  0.699451  ...
# MockInterviewScore   0.649183   0.658725   0.665718   0.674908  0.604555  ...
# ExtraCurricular      0.230759   0.235998   0.238597   0.242093  0.215619  ...
# PlacementStatus      0.693050   0.698077   0.702711   0.708446  0.648488  ...
# IsAnomaly           -0.002921  -0.004223  -0.003451  -0.000188 -0.020003  ...
#
#                     Workshops  Certifications  Publications  \
# StudentID           -0.015969       -0.014361     -0.007597
# SGPA_Sem1            0.534127        0.549925      0.459422
# SGPA_Sem2            0.545746        0.561511      0.468174
# SGPA_Sem3            0.554457        0.569837      0.475172
# SGPA_Sem4            0.564005        0.579227      0.484261
# SGPA_Sem5            0.571617        0.589445      0.491019
# SGPA_Sem6            0.581184        0.598372      0.498286
# SGPA_Sem7            0.586307        0.604930      0.503585
# SGPA_Sem8            0.594862        0.611920      0.510204
# CGPA                 0.531254        0.549611      0.460152
# AttendancePercent    0.604858        0.630974      0.509193
# Internships          0.544368        0.567463      0.486287
# Projects             0.616478        0.644097      0.535457
# Workshops            1.000000        0.678757      0.562691
# Certifications       0.678757        1.000000      0.576064
# Publications         0.562691        0.576064      1.000000
# AptitudeTestScore    0.602153        0.628146      0.506302
# SoftSkillsRating     0.645826        0.668426      0.554844
# CodingTestScore      0.665141        0.688914      0.566120
# MockInterviewScore   0.738375        0.763984      0.633188
# ExtraCurricular      0.263042        0.270127      0.229458
# PlacementStatus      0.582495        0.602582      0.471324
# IsAnomaly           -0.002197        0.005139     -0.005525
#
#                     AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# StudentID                   -0.002452         -0.015393        -0.007285
# SGPA_Sem1                    0.494362          0.521907         0.547556
# SGPA_Sem2                    0.507290          0.532473         0.558873
# SGPA_Sem3                    0.515613          0.540142         0.566620
# SGPA_Sem4                    0.522049          0.548881         0.575112
# SGPA_Sem5                    0.531273          0.559549         0.583649
# SGPA_Sem6                    0.540566          0.567194         0.593697
# SGPA_Sem7                    0.546251          0.572416         0.599674
# SGPA_Sem8                    0.552795          0.580684         0.608087
# CGPA                         0.642761          0.520043         0.699451
# AttendancePercent            0.663001          0.601722         0.719455
# Internships                  0.591541          0.547495         0.643770
# Projects                     0.669022          0.610879         0.729859
# Workshops                    0.602153          0.645826         0.665141
# Certifications               0.628146          0.668426         0.688914
# Publications                 0.506302          0.554844         0.566120
# AptitudeTestScore            1.000000          0.603111         0.809075
# SoftSkillsRating             0.603111          1.000000         0.659882
# CodingTestScore              0.809075          0.659882         1.000000
# MockInterviewScore           0.687846          0.730525         0.753184
# ExtraCurricular              0.247321          0.258490         0.272783
# PlacementStatus              0.577065          0.620296         0.612970
# IsAnomaly                   -0.035514         -0.003818        -0.049053
#
#                     MockInterviewScore  ExtraCurricular  PlacementStatus  \
# StudentID                    -0.009893         0.000922        -0.011653
# SGPA_Sem1                     0.607211         0.216576         0.666083
# SGPA_Sem2                     0.619693         0.220108         0.673924
# SGPA_Sem3                     0.629323         0.224884         0.677951
# SGPA_Sem4                     0.638837         0.224984         0.684598
# SGPA_Sem5                     0.649183         0.230759         0.693050
# SGPA_Sem6                     0.658725         0.235998         0.698077
# SGPA_Sem7                     0.665718         0.238597         0.702711
# SGPA_Sem8                     0.674908         0.242093         0.708446
# CGPA                          0.604555         0.215619         0.648488
# AttendancePercent             0.683062         0.247993         0.552697
# Internships                   0.618959         0.223926         0.523637
# Projects                      0.702253         0.254184         0.577657
# Workshops                     0.738375         0.263042         0.582495
# Certifications                0.763984         0.270127         0.602582
# Publications                  0.633188         0.229458         0.471324
# AptitudeTestScore             0.687846         0.247321         0.577065
# SoftSkillsRating              0.730525         0.258490         0.620296
# CodingTestScore               0.753184         0.272783         0.612970
# MockInterviewScore            1.000000         0.297595         0.669644
# ExtraCurricular               0.297595         1.000000         0.241631
# PlacementStatus               0.669644         0.241631         1.000000
# IsAnomaly                     0.002305         0.004414         0.001676
#
#                     IsAnomaly
# StudentID           -0.005638
# SGPA_Sem1           -0.004832
# SGPA_Sem2           -0.002001
# SGPA_Sem3           -0.002647
# SGPA_Sem4           -0.006361
# SGPA_Sem5           -0.002921
# SGPA_Sem6           -0.004223
# SGPA_Sem7           -0.003451
# SGPA_Sem8           -0.000188
# CGPA                -0.020003
# AttendancePercent   -0.180329
# Internships          0.222246
# Projects             0.227663
# Workshops           -0.002197
# Certifications       0.005139
# Publications        -0.005525
# AptitudeTestScore   -0.035514
# SoftSkillsRating    -0.003818
# CodingTestScore     -0.049053
# MockInterviewScore   0.002305
# ExtraCurricular      0.004414
# PlacementStatus      0.001676
# IsAnomaly            1.000000
#
# [23 rows x 23 columns]

# %%
# Create Heatmap
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.heatmap(
corr_matrix,
annot=True,
cmap="coolwarm",
fmt=".2f",
vmin=-1,
vmax=1,
square=True,
linewidths=0.5
)
plt.title("Correlation Heatmap of Numerical Features", fontsize=14, fontweight="bold")
plt.tight_layout()

# %%
# Export Heatmap
import os
output_dir = "/content/"
heatmap_path = os.path.join(output_dir, "correlation_heatmap.png")
plt.savefig(heatmap_path, dpi=300)
plt.close()
print(f"Exported heatmap to: {heatmap_path}")
# Out:
# Exported heatmap to: /content/correlation_heatmap.png

# %%
# -------------------------------------------------------------
# 3. Produce Boxplots: Numerical Features vs PlacementStatus
# -------------------------------------------------------------
target_col = "PlacementStatus"
if target_col in df.columns:
    for col in numerical_cols:
        plt.figure(figsize=(6, 5))
        sns.boxplot(
            x=target_col,
            y=col,
            data=df,
            palette="Set2",
            hue=target_col,
            legend=False
        )
        plt.title(f"{col} vs {target_col}", fontsize=12, fontweight="bold")
        plt.xlabel(target_col)
        plt.ylabel(col)
        plt.tight_layout()


        # Save the boxplot
        boxplot_filename = f"boxplot_{col}_vs_{target_col}.png"

        # Create complete file path
        boxplot_path = os.path.join(output_dir, boxplot_filename)

        # Save the figure
        plt.savefig(boxplot_path,    dpi=300,    bbox_inches="tight")

        # Close the figure
        plt.close()

        # Display confirmation message
        print(f"Exported boxplot to: {boxplot_path}")

    else:
        print(f"\nTarget column '{target_col}' not found in dataset. Skipping boxplots.")

        print("\nAll EDA tasks completed successfully!")
# Out:
# Exported boxplot to: /content/boxplot_StudentID_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_SGPA_Sem1_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_SGPA_Sem2_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_SGPA_Sem3_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_SGPA_Sem4_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_SGPA_Sem5_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_SGPA_Sem6_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_SGPA_Sem7_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_SGPA_Sem8_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_CGPA_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_AttendancePercent_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_Internships_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_Projects_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_Workshops_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_Certifications_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_Publications_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_AptitudeTestScore_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_SoftSkillsRating_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_CodingTestScore_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_MockInterviewScore_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_ExtraCurricular_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_PlacementStatus_vs_PlacementStatus.png
# Exported boxplot to: /content/boxplot_IsAnomaly_vs_PlacementStatus.png
#
# Target column 'PlacementStatus' not found in dataset. Skipping boxplots.
#
# All EDA tasks completed successfully!

# %%
features = ["AttendancePercent", "Projects", "Certifications", "Publications","AptitudeTestScore", "SoftSkillsRating" ]

fig2=plt.figure(figsize=(15,8))
df[features].hist(
    bins=20
)

plt.tight_layout()

plt.show()
