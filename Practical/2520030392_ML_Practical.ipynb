# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvardhan1699/2520030392_ML/blob/main/Practical/2520030392_ML_Practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Program 1: Variables and Data Types
# Write a Python program to declare variables of type int, float, string, and boolean, and display their values along with their data types.
# Write a program to check the data type of different variables using the type() function.
# Modify the values of the variables and observe how their data types change.
# Create your own variables representing a student's details and print their values and data types.

# %%
roll = 2520030018
cgpa = 9.43
clg = 'KLH'
passed = True

print(f"value:{roll},type:{type(roll)}")
print(f"value:{cgpa},type:{type(cgpa)}")
print(f"value:{clg},type:{type(clg)}")
print(f"value:{passed},type:{type(passed)}")
# Out:
# value:2520030018,type:<class 'int'>
# value:9.43,type:<class 'float'>
# value:KLH,type:<class 'str'>
# value:True,type:<class 'bool'>

# %%
a = 100
b = 45.8
c = "Python"
d = False

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
value = 25
print(f"Value:{value}, type:{type(value)}")

value = 25.75
print("\nValue =", value)
print("Type =", type(value))

value = "Twenty Five"
print("\nValue =", value)
print("Type =", type(value))

value = True
print("\nValue =", value)
print("Type =", type(value))
# Out:
# Value:25, type:<class 'int'>
#
# Value = 25.75
# Type = <class 'float'>
#
# Value = Twenty Five
# Type = <class 'str'>
#
# Value = True
# Type = <class 'bool'>

# %%
student_name = "Vishnu Vardhan"
roll_number = 2520030392
cgpa = 8.62
hosteller = True

print("Student Name :", student_name)
print("Type :", type(student_name))

print("Roll Number :", roll_number)
print("Type :", type(roll_number))

print("CGPA :", cgpa)
print("Type :", type(cgpa))

print("Hosteller :", hosteller)
print("Type :", type(hosteller))
# Out:
# Student Name : Vishnu Vardhan
# Type : <class 'str'>
# Roll Number : 2520030392
# Type : <class 'int'>
# CGPA : 8.62
# Type : <class 'float'>
# Hosteller : True
# Type : <class 'bool'>

# %% [markdown]
# Program 2: Operators
# Write a Python program to demonstrate arithmetic operators.
# Write a program to demonstrate comparison operators using two numbers.
# Write a program to demonstrate logical operators (and, or, not).
# Write a program to determine whether a student is eligible for placement based on CGPA and attendance using logical operators.

# %%
a = 20
b = 6

print("First Number =", a)
print("Second Number =", b)

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
print("Floor Division =", a // b)
print("Modulus =", a % b)
print("Exponent =", a ** b)
# Out:
# First Number = 20
# Second Number = 6
# Addition = 26
# Subtraction = 14
# Multiplication = 120
# Division = 3.3333333333333335
# Floor Division = 3
# Modulus = 2
# Exponent = 64000000

# %%
x = 18
y = 25

print("x =", x)
print("y =", y)

print("x == y :", x == y)
print("x != y :", x != y)
print("x > y :", x > y)
print("x < y :", x < y)
print("x >= y :", x >= y)
print("x <= y :", x <= y)
# Out:
# x = 18
# y = 25
# x == y : False
# x != y : True
# x > y : False
# x < y : True
# x >= y : False
# x <= y : True

# %%
a = True
b = False

print("a =", a)
print("b =", b)

print("a and b =", a and b)
print("a or b =", a or b)
print("not a =", not a)
print("not b =", not b)
# Out:
# a = True
# b = False
# a and b = False
# a or b = True
# not a = False
# not b = True

# %%
cgpa = 8.62
attendance = 82

print("CGPA =", cgpa)
print("Attendance =", attendance)

eligible = (cgpa >= 7.0) and (attendance >= 75)

print("Eligible for Placement =", eligible)
# Out:
# CGPA = 8.62
# Attendance = 82
# Eligible for Placement = True

# %% [markdown]
# Program-3

# %%
model_name = "Logistic Regression"
accuracy = 0.87345


print("Accuracy of " + model_name + " is " + str(accuracy))


print(f"Accuracy of {model_name} is {accuracy}")


print(f"Accuracy of {model_name} is {accuracy:.3f}")
# Out:
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.873

# %% [markdown]
# Program 4: Lists and Indexing
# Write a Python program to create a list and access its elements using indexing.
# Write a program to display the first, second, and last elements of a list.
# Write a program to demonstrate list slicing.
# Write a program to add a new element to an existing list using the append() method.
# Write a program to display the total number of elements in a list.

# %%
colors = ["Red", "Blue", "Green", "Yellow", "Black"]

print("Complete List:", colors)

print("First Element:", colors[0])
print("Third Element:", colors[2])
print("Last Element:", colors[4])
# Out:
# Complete List: ['Red', 'Blue', 'Green', 'Yellow', 'Black']
# First Element: Red
# Third Element: Green
# Last Element: Black

# %%
subjects = ["Python", "Java", "C", "C++", "HTML"]

print("First Subject:", subjects[0])
print("Second Subject:", subjects[1])
print("Last Subject:", subjects[4])
# Out:
# First Subject: Python
# Second Subject: Java
# Last Subject: HTML

# %%
numbers = [5, 10, 15, 20, 25, 30, 35]

print("Original List:", numbers)

print("First Three Elements:", numbers[:3])
print("Middle Elements:", numbers[2:5])
print("Last Three Elements:", numbers[4:7])
# Out:
# Original List: [5, 10, 15, 20, 25, 30, 35]
# First Three Elements: [5, 10, 15]
# Middle Elements: [15, 20, 25]
# Last Three Elements: [25, 30, 35]

# %%
fruits = ["Apple", "Banana", "Orange"]

print("Before Append:", fruits)

fruits.append("Mango")

print("After Append:", fruits)
# Out:
# Before Append: ['Apple', 'Banana', 'Orange']
# After Append: ['Apple', 'Banana', 'Orange', 'Mango']

# %% [markdown]
# Program 5: Dictionaries
# Write a Python program to create a dictionary and display all its key-value pairs.
# Write a program to access the value associated with a specific key in a dictionary.
# Write a program to iterate through a dictionary using the items() method.
# Write a program to store different machine learning models in a dictionary and display their names and objects.

# %%
student = {
    "Name": "Vishnu Vardhan",
    "Roll No": 2520030392,
    "Branch": "CSE",
    "CGPA": 8.62
}

print("Student Details:")

for key, value in student.items():
    print(key, ":", value)
# Out:
# Student Details:
# Name : Vishnu Vardhan
# Roll No : 2520030092
# Branch : CSE
# CGPA : 8.62

# %%
employee = {
    "ID": 2520030392,
    "Name": "Vishnu Vardhan",
    "Department": "IT",
    "Salary": 90000
}

print("Employee Name:", employee["Name"])
print("Department:", employee["Department"])
print("ID no:", employee["ID"])
print("Salary:",employee["Salary"])
# Out:
# Employee Name: Vishnu Vardhan
# Department: IT
# ID no: 2520030392
# Salary: 90000

# %%
book = {
    "Title": "Python Programming",
    "Author": "John",
    "Price": 550,
    "Publisher": "ABC Publications"
}

print("Book Details:")

for key, value in book.items():
    print(key, "=", value)
# Out:
# Book Details:
# Title = Python Programming
# Author = John
# Price = 550
# Publisher = ABC Publications

# %%
ml_models = {
    "Linear Regression": "Regression Model",
    "Decision Tree": "Tree-Based Model",
    "Random Forest": "Ensemble Model",
    "Support Vector Machine": "Classification Model",
    "K-Nearest Neighbors": "Instance-Based Model"
}

print("Machine Learning Models:\n")

for model, description in ml_models.items():
    print(model, ":", description)
# Out:
# Machine Learning Models:
#
# Linear Regression : Regression Model
# Decision Tree : Tree-Based Model
# Random Forest : Ensemble Model
# Support Vector Machine : Classification Model
# K-Nearest Neighbors : Instance-Based Model

# %% [markdown]
# Program 6: Conditional Statements
# Write a Python program to classify a student's CGPA into High, Mid, or Low categories using if-elif-else.
# Write a program to check whether missing values are present in a dataset using conditional statements.
# Write a program to determine whether a student is eligible for placement based on CGPA.
# Write a program that uses if-elif-else to assign grades based on marks.

# %%
cgpa = float(input("Enter CGPA: "))

if cgpa >= 8.5:
    print("Category: High")
elif cgpa >= 6.5:
    print("Category: Mid")
else:
    print("Category: Low")
# Out:
# Enter CGPA: 8.62
# Category: High

# %%
dataset = [45, 67, None, 89, 72]

if None in dataset:
    print("Missing values are present in the dataset.")
else:
    print("No missing values found.")
# Out:
# Missing values are present in the dataset.

# %%
cgpa = float(input("Enter CGPA: "))

if cgpa >= 7.0:
    print("Student is Eligible for Placement.")
else:
    print("Student is Not Eligible for Placement.")
# Out:
# Enter CGPA: 8.62
# Student is Eligible for Placement.

# %%
marks = int(input("Enter Marks: "))

if marks >= 90:
    print("Grade: A")
elif marks >= 75:
    print("Grade: B")
elif marks >= 60:
    print("Grade: C")
elif marks >= 40:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Enter Marks: 862
# Grade: A

# %% [markdown]
# Program 7: Loops
# Write a Python program to display all elements in a list using a for loop.
# Write a program to calculate the average of numbers stored in a list.
# Write a program to display only the values greater than a given threshold using a loop.
# Write a program to find the maximum and minimum values in a list using loops.
# Write a program to count the number of elements satisfying a given condition using a loop.

# %%
numbers = [12, 25, 37, 48, 59]

print("Elements in the list:")

for num in numbers:
    print(num)
# Out:
# Elements in the list:
# 12
# 25
# 37
# 48
# 59

# %%
marks = [80, 75, 90, 85, 70]

total = 0

for mark in marks:
    total += mark

average = total / len(marks)

print("Marks:", marks)
print("Average =", average)
# Out:
# Marks: [80, 75, 90, 85, 70]
# Average = 80.0

# %%
numbers = [10, 45, 67, 23, 89, 34]
threshold = 40

print("Values greater than", threshold, ":")

for num in numbers:
    if num > threshold:
        print(num)
# Out:
# Values greater than 40 :
# 45
# 67
# 89

# %%
numbers = [25, 14, 68, 9, 41, 55]

maximum = numbers[0]
minimum = numbers[0]

for num in numbers:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

print("Maximum Value =", maximum)
print("Minimum Value =", minimum)
# Out:
# Maximum Value = 68
# Minimum Value = 9

# %%
numbers = [12, 15, 18, 21, 24, 30, 35]

count = 0

for num in numbers:
    if num % 2 == 0:
        count += 1

print("List:", numbers)
print("Number of Even Elements =", count)
# Out:
# List: [12, 15, 18, 21, 24, 30, 35]
# Number of Even Elements = 4
